# %% [markdown]
# ***Today starting with logistic regression and this part 1 of the project***

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns 


model=load_iris()
dir(model)
model.data[0]


from sklearn.model_selection import train_test_split
train=LogisticRegression()
x_train,x_test,y_train,y_test=train_test_split(model.data,model.target,test_size=0.2,random_state=10)
train.fit(x_train,y_train)

train.predict(x_test)
train.score(x_test,y_test)
# Out:
# 1.0

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x_test[:, 0], y=x_test[:, 1], hue=predictions, palette='viridis', style=y_test)
plt.title('Logistic Regression Predictions on Iris Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
#optional
from sklearn.metrics import confusion_matrix
y_pred=train.predict(x_test)

cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm)
# Out:
# <Axes: >

# %% [markdown]
# ***this heatmap does not make much sense but anyway has been showed***
